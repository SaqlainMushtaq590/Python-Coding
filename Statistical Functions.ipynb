# %%
import numpy as np
a = np.array([6,5,12,74,6])
print(np.std(a))
# Out:
# 26.81492121935099

# %%
s = np.empty((3,2))
print(s)
# Out:
# [[8.68849821e-071 3.21619382e-057]
#  [4.11832154e-033 5.49727102e+170]
#  [0.00000000e+000 1.05699581e-307]]

# %%
a = np.array([34,56,75,23])
b = np.array([1,2,3,4,])

s = np.average(a,weights=b)
print(s)
# Out:
# 46.3

# %%
a = np.array([3,0,7,3])
print(np.all(a))
# Out:
# False
